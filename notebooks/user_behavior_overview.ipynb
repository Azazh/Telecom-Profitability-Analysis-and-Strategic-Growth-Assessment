# %%
import sys
import os
# Add the parent directory to the Python path
sys.path.append(os.path.abspath(".."))

from scripts.user_behavior_analysis import UserBehaviorAnalysis

# %%
# load dataset
analysis = UserBehaviorAnalysis("../data/Week2_challenge_data_source.csv")

# %%
aggregated_data = analysis.aggregate_user_data()

# %%
analysis.plot_aggregated_data()
analysis.print_insights()
# Out:
# Total xDR Sessions: 148935
# Total Data Volume: 73833.45 GB
#
# Top Applications by Data Volume:
# gaming_data: 62854.38 GB
# other_data: 62723.57 GB
# youtube_data: 1732.63 GB
# netflix_data: 1731.75 GB
# google_data: 856.61 GB
# social_media_data: 267.36 GB
# email_data: 266.86 GB
#
# Top 5 Users by Session Duration:
#        MSISDN/Number  session_duration
# 13180   3.362578e+10        18553754.0
# 6437    3.361489e+10         9966898.0
# 92923   3.376054e+10         9279434.0
# 13526   3.362632e+10         8791927.0
# 65118   3.366716e+10         8744914.0
