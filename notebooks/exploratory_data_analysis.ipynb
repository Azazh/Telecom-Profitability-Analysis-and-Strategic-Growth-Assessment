# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath("../scripts"))
import db_config
from exploratory_data_analysis import ExploratoryDataAnalysis

# %% [markdown]
# ### SQL query to fetch the required dataset

# %%
QUERY = "SELECT * FROM xdr_data"

# %% [markdown]
# #### Initialize the analysis class with the SQL query

# %%
data=db_config.fetch_data(QUERY)
eda = ExploratoryDataAnalysis(data)

# %%
eda.load_data()
eda.describe_variables()
eda.handle_missing_values()
eda.handle_outliers("Dur. (ms)")
# Out:
# Dataset loaded successfully.
# Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
#  10  Avg RTT DL (ms)                           122172 non-null  float64
#  11  Avg RTT UL (ms)                           122189 non-null  float64
#  12  Avg Bearer TP DL (kbps)                   150000 non-null  float64
#  13  Avg Bearer TP UL (kbps)                   150000 non-null  float64
#  14  TCP DL Retrans. Vol (Bytes)               61855 non-null   float64
#  15  TCP UL Retrans. Vol (Bytes)               53352 non-null   float64
#  16  DL TP < 50 Kbps (%)                       149247 non-null  float64
#  17  50 Kbps < DL TP < 250 Kbps (%)            149247 non-null  float64
#  18  250 Kbps < DL TP < 1 Mbps (%)             149247 non-null  float64
#  19  DL TP > 1 Mbps (%)                        149247 non-null  float64
#  20  UL TP < 10 Kbps (%)                       149209 non-null  float64
#  21  10 Kbps < UL TP < 50 Kbps (%)             149209 non-null  float64
#  22  50 Kbps < UL TP < 300 Kbps (%)            149209 non-null  float64
#  23  UL TP > 300 Kbps (%)                      149209 non-null  float64
#  24  HTTP DL (Bytes)                           68527 non-null   float64
#  25  HTTP UL (Bytes)                           68191 non-null   float64
#  26  Activity Duration DL (ms)                 150000 non-null  float64
#  27  Activity Duration UL (ms)                 150000 non-null  float64
#  28  Dur. (ms).1                               150000 non-null  float64
#  29  Handset Manufacturer                      149429 non-null  object
#  30  Handset Type                              149429 non-null  object
#  31  Nb of sec with 125000B < Vol DL           52463 non-null   float64
#  32  Nb of sec with 1250B < Vol UL < 6250B     57107 non-null   float64
#  33  Nb of sec with 31250B < Vol DL < 125000B  56415 non-null   float64
#  34  Nb of sec with 37500B < Vol UL            19747 non-null   float64
#  35  Nb of sec with 6250B < Vol DL < 31250B    61684 non-null   float64
#  36  Nb of sec with 6250B < Vol UL < 37500B    38158 non-null   float64
#  37  Nb of sec with Vol DL < 6250B             149246 non-null  float64
#  38  Nb of sec with Vol UL < 1250B             149208 non-null  float64
#  39  Social Media DL (Bytes)                   150001 non-null  float64
#  40  Social Media UL (Bytes)                   150001 non-null  float64
#  41  Google DL (Bytes)                         150001 non-null  float64
#  42  Google UL (Bytes)                         150001 non-null  float64
#  43  Email DL (Bytes)                          150001 non-null  float64
#  44  Email UL (Bytes)                          150001 non-null  float64
#  45  Youtube DL (Bytes)                        150001 non-null  float64
#  46  Youtube UL (Bytes)                        150001 non-null  float64
#  47  Netflix DL (Bytes)                        150001 non-null  float64
#  48  Netflix UL (Bytes)                        150001 non-null  float64
#  49  Gaming DL (Bytes)                         150001 non-null  float64
#  50  Gaming UL (Bytes)                         150001 non-null  float64
#  51  Other DL (Bytes)                          150001 non-null  float64
#  52  Other UL (Bytes)                          150001 non-null  float64
#  53  Total UL (Bytes)                          150000 non-null  float64
#  54  Total DL (Bytes)                          150000 non-null  float64
# dtypes: float64(50), object(5)
# memory usage: 62.9+ MB
# None
# Summary Statistics:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# std     2.447443e+12  2.241637e+13       619.782739        84.793524
# min     3.360100e+10  4.400152e+11         0.000000         0.000000
# 25%     3.365130e+10  3.546071e+13        32.000000         2.000000
# 50%     3.366371e+10  3.572201e+13        45.000000         5.000000
# 75%     3.368349e+10  8.611970e+13        70.000000        15.000000
# max     8.823971e+14  9.900120e+13     96923.000000      7120.000000
#
#        Avg Bearer TP DL (kbps)  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# count            150000.000000  ...        1.500010e+05        1.500010e+05
# mean              13300.045927  ...        1.163407e+07        1.100941e+07
# std               23971.878541  ...        6.710569e+06        6.345423e+06
# min                   0.000000  ...        5.300000e+01        1.050000e+02
# 25%                  43.000000  ...        5.833501e+06        5.517965e+06
# 50%                  63.000000  ...        1.161602e+07        1.101345e+07
# 75%               19710.750000  ...        1.744852e+07        1.651556e+07
# max              378160.000000  ...        2.325910e+07        2.201196e+07
#
#        Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# count        1.500010e+05        1.500010e+05       1.500010e+05
# mean         1.162685e+07        1.100175e+07       4.220447e+08
# std          6.725218e+06        6.359490e+06       2.439675e+08
# min          4.200000e+01        3.500000e+01       2.516000e+03
# 25%          5.777156e+06        5.475981e+06       2.104733e+08
# 50%          1.164222e+07        1.099638e+07       4.234081e+08
# 75%          1.747048e+07        1.650727e+07       6.331742e+08
# max          2.325919e+07        2.201196e+07       8.434419e+08
#
#        Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# count       1.500010e+05      1.500010e+05      1.500010e+05
# mean        8.288398e+06      4.211005e+08      8.264799e+06
# std         4.782700e+06      2.432050e+08      4.769004e+06
# min         5.900000e+01      3.290000e+03      1.480000e+02
# 25%         4.128476e+06      2.101869e+08      4.145943e+06
# 50%         8.291208e+06      4.218030e+08      8.267071e+06
# 75%         1.243162e+07      6.316918e+08      1.238415e+07
# max         1.655879e+07      8.434425e+08      1.655882e+07
#
#        Total UL (Bytes)  Total DL (Bytes)
# count      1.500000e+05      1.500000e+05
# mean       4.112121e+07      4.546434e+08
# std        1.127639e+07      2.441429e+08
# min        2.866892e+06      7.114041e+06
# 25%        3.322201e+07      2.431068e+08
# 50%        4.114331e+07      4.558411e+08
# 75%        4.903424e+07      6.657055e+08
# max        7.833131e+07      9.029696e+08
#
# [8 rows x 50 columns]
# Missing values replaced with column means.
# "Outliers in 'Dur. (ms)' handled."

# %% [markdown]
# ### Clean the dataset

# %%
eda.clean_data()
# Out:
# Data cleaning completed.
# /home/azazh/Documents/10-acadamy/w-2/Telecom_Profitability_Analysis_and_Strategic_Growth_Assessment/scripts/exploratory_data_analysis.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data[col] = pd.to_numeric(self.data[col], errors="coerce")
# /home/azazh/Documents/10-acadamy/w-2/Telecom_Profitability_Analysis_and_Strategic_Growth_Assessment/scripts/exploratory_data_analysis.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data.fillna(0, inplace=True)

# %% [markdown]
# ### Calculate metrics

# %%
eda.calculate_metrics()
# Out:
# Metrics calculation completed.
# /home/azazh/Documents/10-acadamy/w-2/Telecom_Profitability_Analysis_and_Strategic_Growth_Assessment/scripts/exploratory_data_analysis.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data["Total Duration"] = self.data.groupby("MSISDN/Number")["Dur. (ms)"].transform("sum")
# /home/azazh/Documents/10-acadamy/w-2/Telecom_Profitability_Analysis_and_Strategic_Growth_Assessment/scripts/exploratory_data_analysis.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data["Total Data"] = self.data["Total DL (Bytes)"] + self.data["Total UL (Bytes)"]

# %% [markdown]
# ### Segment users and calculate total data per decile

# %%
eda.segment_users_by_deciles()
# Out:
# Decile segmentation completed.
# /home/azazh/Documents/10-acadamy/w-2/Telecom_Profitability_Analysis_and_Strategic_Growth_Assessment/scripts/exploratory_data_analysis.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data["Duration Decile"] = pd.qcut(self.data["Total Duration"], 10, labels=False) + 1

# %%
# Plot the decile summary
eda.plot_decile_summary()
# Out:
# Duration Decile: [10, 9, 8, 7, 6]
# Total Data: [7414042047640.0, 7411642704829.0, 7446793371329.0, 6778634847993.0, 8095113447184.0]
# /home/azazh/Documents/10-acadamy/w-2/Telecom_Profitability_Analysis_and_Strategic_Growth_Assessment/scripts/exploratory_data_analysis.py:148: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
eda.analyze_basic_metrics()
# Out:
# '=== Basic Metrics Analysis ==='
# Mean Values:
# Bearer Id                                   1.013887e+19
# Start ms                                    4.991882e+02
# End ms                                      4.988009e+02
# Dur. (ms)                                   9.957213e+04
# IMSI                                        2.082016e+14
# MSISDN/Number                               4.188282e+10
# IMEI                                        4.847455e+13
# Avg RTT DL (ms)                             1.097957e+02
# Avg RTT UL (ms)                             1.766288e+01
# Avg Bearer TP DL (kbps)                     1.330005e+04
# Avg Bearer TP UL (kbps)                     1.770429e+03
# TCP DL Retrans. Vol (Bytes)                 2.080991e+07
# TCP UL Retrans. Vol (Bytes)                 7.596587e+05
# DL TP < 50 Kbps (%)                         9.284475e+01
# 50 Kbps < DL TP < 250 Kbps (%)              3.069355e+00
# 250 Kbps < DL TP < 1 Mbps (%)               1.717341e+00
# DL TP > 1 Mbps (%)                          1.609654e+00
# UL TP < 10 Kbps (%)                         9.853014e+01
# 10 Kbps < UL TP < 50 Kbps (%)               7.767494e-01
# 50 Kbps < UL TP < 300 Kbps (%)              1.479871e-01
# UL TP > 300 Kbps (%)                        7.892285e-02
# HTTP DL (Bytes)                             1.144710e+08
# HTTP UL (Bytes)                             3.242301e+06
# Activity Duration DL (ms)                   1.829177e+06
# Activity Duration UL (ms)                   1.408880e+06
# Dur. (ms).1                                 1.046091e+08
# Nb of sec with 125000B < Vol DL             9.897000e+02
# Nb of sec with 1250B < Vol UL < 6250B       3.404344e+02
# Nb of sec with 31250B < Vol DL < 125000B    8.108374e+02
# Nb of sec with 37500B < Vol UL              1.492571e+02
# Nb of sec with 6250B < Vol DL < 31250B      9.654648e+02
# Nb of sec with 6250B < Vol UL < 37500B      1.413048e+02
# Nb of sec with Vol DL < 6250B               3.719788e+03
# Nb of sec with Vol UL < 1250B               4.022083e+03
# Social Media DL (Bytes)                     1.795322e+06
# Social Media UL (Bytes)                     3.292843e+04
# Google DL (Bytes)                           5.750753e+06
# Google UL (Bytes)                           2.056542e+06
# Email DL (Bytes)                            1.791729e+06
# Email UL (Bytes)                            4.673734e+05
# Youtube DL (Bytes)                          1.163407e+07
# Youtube UL (Bytes)                          1.100941e+07
# Netflix DL (Bytes)                          1.162685e+07
# Netflix UL (Bytes)                          1.100175e+07
# Gaming DL (Bytes)                           4.220447e+08
# Gaming UL (Bytes)                           8.288398e+06
# Other DL (Bytes)                            4.211005e+08
# Other UL (Bytes)                            8.264799e+06
# Total UL (Bytes)                            4.112121e+07
# Total DL (Bytes)                            4.546434e+08
# dtype: float64
# Median Values:
# Bearer Id                                   7.349883e+18
# Start ms                                    4.990000e+02
# End ms                                      5.000000e+02
# Dur. (ms)                                   8.639900e+04
# IMSI                                        2.082015e+14
# MSISDN/Number                               3.366380e+10
# IMEI                                        3.572241e+13
# Avg RTT DL (ms)                             5.400000e+01
# Avg RTT UL (ms)                             7.000000e+00
# Avg Bearer TP DL (kbps)                     6.300000e+01
# Avg Bearer TP UL (kbps)                     6.300000e+01
# TCP DL Retrans. Vol (Bytes)                 2.080991e+07
# TCP UL Retrans. Vol (Bytes)                 7.596587e+05
# DL TP < 50 Kbps (%)                         1.000000e+02
# 50 Kbps < DL TP < 250 Kbps (%)              0.000000e+00
# 250 Kbps < DL TP < 1 Mbps (%)               0.000000e+00
# DL TP > 1 Mbps (%)                          0.000000e+00
# UL TP < 10 Kbps (%)                         1.000000e+02
# 10 Kbps < UL TP < 50 Kbps (%)               0.000000e+00
# 50 Kbps < UL TP < 300 Kbps (%)              0.000000e+00
# UL TP > 300 Kbps (%)                        0.000000e+00
# HTTP DL (Bytes)                             1.144710e+08
# HTTP UL (Bytes)                             3.242301e+06
# Activity Duration DL (ms)                   3.930500e+04
# Activity Duration UL (ms)                   4.679400e+04
# Dur. (ms).1                                 8.639998e+07
# Nb of sec with 125000B < Vol DL             9.897000e+02
# Nb of sec with 1250B < Vol UL < 6250B       3.404344e+02
# Nb of sec with 31250B < Vol DL < 125000B    8.108374e+02
# Nb of sec with 37500B < Vol UL              1.492571e+02
# Nb of sec with 6250B < Vol DL < 31250B      9.654648e+02
# Nb of sec with 6250B < Vol UL < 37500B      1.413048e+02
# Nb of sec with Vol DL < 6250B               2.050000e+02
# Nb of sec with Vol UL < 1250B               2.200000e+02
# Social Media DL (Bytes)                     1.794369e+06
# Social Media UL (Bytes)                     3.292000e+04
# Google DL (Bytes)                           5.765829e+06
# Google UL (Bytes)                           2.054573e+06
# Email DL (Bytes)                            1.793505e+06
# Email UL (Bytes)                            4.662500e+05
# Youtube DL (Bytes)                          1.161602e+07
# Youtube UL (Bytes)                          1.101345e+07
# Netflix DL (Bytes)                          1.164222e+07
# Netflix UL (Bytes)                          1.099638e+07
# Gaming DL (Bytes)                           4.234081e+08
# Gaming UL (Bytes)                           8.291208e+06
# Other DL (Bytes)                            4.218030e+08
# Other UL (Bytes)                            8.267071e+06
# Total UL (Bytes)                            4.114324e+07
# Total DL (Bytes)                            4.558409e+08
# dtype: float64
# Standard Deviation:
# Bearer Id                                   2.883600e+18
# Start ms                                    2.886109e+02
# End ms                                      2.880967e+02
# Dur. (ms)                                   5.908418e+04
# IMSI                                        2.144722e+10
# MSISDN/Number                               2.438731e+12
# IMEI                                        2.237359e+13
# Avg RTT DL (ms)                             5.593426e+02
# Avg RTT UL (ms)                             7.652993e+01
# Avg Bearer TP DL (kbps)                     2.397180e+04
# Avg Bearer TP UL (kbps)                     4.625340e+03
# TCP DL Retrans. Vol (Bytes)                 1.172356e+08
# TCP UL Retrans. Vol (Bytes)                 1.577616e+07
# DL TP < 50 Kbps (%)                         1.300522e+01
# 50 Kbps < DL TP < 250 Kbps (%)              6.199592e+00
# 250 Kbps < DL TP < 1 Mbps (%)               4.149070e+00
# DL TP > 1 Mbps (%)                          4.816738e+00
# UL TP < 10 Kbps (%)                         4.622035e+00
# 10 Kbps < UL TP < 50 Kbps (%)               3.216651e+00
# 50 Kbps < UL TP < 300 Kbps (%)              1.620229e+00
# UL TP > 300 Kbps (%)                        1.291972e+00
# HTTP DL (Bytes)                             6.510226e+08
# HTTP UL (Bytes)                             1.319532e+07
# Activity Duration DL (ms)                   5.696376e+06
# Activity Duration UL (ms)                   4.643215e+06
# Dur. (ms).1                                 8.103734e+07
# Nb of sec with 125000B < Vol DL             1.505999e+03
# Nb of sec with 1250B < Vol UL < 6250B       8.918109e+02
# Nb of sec with 31250B < Vol DL < 125000B    1.129733e+03
# Nb of sec with 37500B < Vol UL              4.423211e+02
# Nb of sec with 6250B < Vol DL < 31250B      1.248149e+03
# Nb of sec with 6250B < Vol UL < 37500B      5.010068e+02
# Nb of sec with Vol DL < 6250B               9.148498e+03
# Nb of sec with Vol UL < 1250B               1.013343e+04
# Social Media DL (Bytes)                     1.035482e+06
# Social Media UL (Bytes)                     1.900618e+04
# Google DL (Bytes)                           3.309097e+06
# Google UL (Bytes)                           1.189917e+06
# Email DL (Bytes)                            1.035840e+06
# Email UL (Bytes)                            2.699693e+05
# Youtube DL (Bytes)                          6.710569e+06
# Youtube UL (Bytes)                          6.345423e+06
# Netflix DL (Bytes)                          6.725218e+06
# Netflix UL (Bytes)                          6.359490e+06
# Gaming DL (Bytes)                           2.439675e+08
# Gaming UL (Bytes)                           4.782700e+06
# Other DL (Bytes)                            2.432050e+08
# Other UL (Bytes)                            4.769004e+06
# Total UL (Bytes)                            1.127635e+07
# Total DL (Bytes)                            2.441421e+08
# dtype: float64
# === Insights ===

# %%
dispersion_stats = eda.compute_dispersion()
# print(dispersion_stats)
display(dispersion_stats)
# Out:
#                      count          mean           std     min           25%  \
# Dur. (ms)         150001.0  1.046079e+05  8.103780e+04     0.0  5.743600e+04
# Total DL (Bytes)  150001.0  4.546404e+08  2.441449e+08     0.0  2.431057e+08
# Total UL (Bytes)  150001.0  4.112093e+07  1.127685e+07     0.0  3.322196e+07
# MSISDN/Number     150001.0  4.158517e+10  2.438734e+12     0.0  3.365094e+10
# Total Duration    150001.0  7.280141e+05  6.081390e+06  7142.0  8.631100e+04
# Total Data        150001.0  4.957613e+08  2.443843e+08     0.0  2.844744e+08
# Duration Decile   150001.0  5.480870e+00  2.876425e+00     1.0  3.000000e+00
#
#                            50%           75%           max         range  \
# Dur. (ms)         8.639900e+04  1.324300e+05  1.859336e+06  1.859336e+06
# Total DL (Bytes)  4.558409e+08  6.657051e+08  9.029696e+08  9.029696e+08
# Total UL (Bytes)  4.114324e+07  4.903424e+07  7.833131e+07  7.833131e+07
# MSISDN/Number     3.366361e+10  3.368307e+10  8.823971e+14  8.823971e+14
# Total Duration    1.398550e+05  2.533120e+05  7.244640e+07  7.243925e+07
# Total Data        4.968610e+08  7.065054e+08  9.559848e+08  9.559848e+08
# Duration Decile   5.000000e+00  8.000000e+00  1.000000e+01  9.000000e+00
#
#                           IQR
# Dur. (ms)             74994.0
# Total DL (Bytes)  422599445.0
# Total UL (Bytes)   15812283.0
# MSISDN/Number      32133097.0
# Total Duration       167001.0
# Total Data        422031041.0
# Duration Decile           5.0

# %%
# eda.plot_univariate()

# %% [markdown]
# ### Univariate Analysis

# %%
eda.univariate_analysis()
# eda.graphical_univariate_analysis()
# Out:
# === Non-Graphical Univariate Analysis ===
#
# Range Values:
# Bearer Id                                   6.269004e+18
# Start ms                                    9.990000e+02
# End ms                                      9.990000e+02
# Dur. (ms)                                   2.377700e+05
# IMSI                                        1.002719e+13
# MSISDN/Number                               8.823635e+14
# IMEI                                        9.856119e+13
# Avg RTT DL (ms)                             9.692300e+04
# Avg RTT UL (ms)                             7.120000e+03
# Avg Bearer TP DL (kbps)                     3.781600e+05
# Avg Bearer TP UL (kbps)                     5.861300e+04
# TCP DL Retrans. Vol (Bytes)                 4.294426e+09
# TCP UL Retrans. Vol (Bytes)                 2.908226e+09
# DL TP < 50 Kbps (%)                         1.000000e+02
# 50 Kbps < DL TP < 250 Kbps (%)              9.300000e+01
# 250 Kbps < DL TP < 1 Mbps (%)               1.000000e+02
# DL TP > 1 Mbps (%)                          9.400000e+01
# UL TP < 10 Kbps (%)                         1.000000e+02
# 10 Kbps < UL TP < 50 Kbps (%)               9.800000e+01
# 50 Kbps < UL TP < 300 Kbps (%)              1.000000e+02
# UL TP > 300 Kbps (%)                        9.600000e+01
# HTTP DL (Bytes)                             7.253064e+10
# HTTP UL (Bytes)                             1.491890e+09
# Activity Duration DL (ms)                   1.365365e+08
# Activity Duration UL (ms)                   1.449113e+08
# Dur. (ms).1                                 1.852193e+09
# Nb of sec with 125000B < Vol DL             8.147500e+04
# Nb of sec with 1250B < Vol UL < 6250B       8.541100e+04
# Nb of sec with 31250B < Vol DL < 125000B    5.852400e+04
# Nb of sec with 37500B < Vol UL              5.055200e+04
# Nb of sec with 6250B < Vol DL < 31250B      6.691200e+04
# Nb of sec with 6250B < Vol UL < 37500B      4.956400e+04
# Nb of sec with Vol DL < 6250B               6.040600e+05
# Nb of sec with Vol UL < 1250B               6.041210e+05
# Social Media DL (Bytes)                     3.586052e+06
# Social Media UL (Bytes)                     6.587000e+04
# Google DL (Bytes)                           1.146262e+07
# Google UL (Bytes)                           4.121354e+06
# Email DL (Bytes)                            3.586132e+06
# Email UL (Bytes)                            9.364160e+05
# Youtube DL (Bytes)                          2.325904e+07
# Youtube UL (Bytes)                          2.201186e+07
# Netflix DL (Bytes)                          2.325915e+07
# Netflix UL (Bytes)                          2.201192e+07
# Gaming DL (Bytes)                           8.434394e+08
# Gaming UL (Bytes)                           1.655874e+07
# Other DL (Bytes)                            8.434392e+08
# Other UL (Bytes)                            1.655867e+07
# Total UL (Bytes)                            7.546442e+07
# Total DL (Bytes)                            8.958556e+08
# dtype: float64
# Variance Values:
# Bearer Id                                   8.315146e+36
# Start ms                                    8.329624e+04
# End ms                                      8.299970e+04
# Dur. (ms)                                   3.490941e+09
# IMSI                                        4.599834e+20
# MSISDN/Number                               5.947410e+24
# IMEI                                        5.005776e+26
# Avg RTT DL (ms)                             3.128642e+05
# Avg RTT UL (ms)                             5.856831e+03
# Avg Bearer TP DL (kbps)                     5.746471e+08
# Avg Bearer TP UL (kbps)                     2.139377e+07
# TCP DL Retrans. Vol (Bytes)                 1.374418e+16
# TCP UL Retrans. Vol (Bytes)                 2.488873e+14
# DL TP < 50 Kbps (%)                         1.691358e+02
# 50 Kbps < DL TP < 250 Kbps (%)              3.843494e+01
# 250 Kbps < DL TP < 1 Mbps (%)               1.721478e+01
# DL TP > 1 Mbps (%)                          2.320097e+01
# UL TP < 10 Kbps (%)                         2.136320e+01
# 10 Kbps < UL TP < 50 Kbps (%)               1.034684e+01
# 50 Kbps < UL TP < 300 Kbps (%)              2.625142e+00
# UL TP > 300 Kbps (%)                        1.669191e+00
# HTTP DL (Bytes)                             4.238305e+17
# HTTP UL (Bytes)                             1.741164e+14
# Activity Duration DL (ms)                   3.244870e+13
# Activity Duration UL (ms)                   2.155945e+13
# Dur. (ms).1                                 6.567051e+15
# Nb of sec with 125000B < Vol DL             2.268033e+06
# Nb of sec with 1250B < Vol UL < 6250B       7.953267e+05
# Nb of sec with 31250B < Vol DL < 125000B    1.276296e+06
# Nb of sec with 37500B < Vol UL              1.956479e+05
# Nb of sec with 6250B < Vol DL < 31250B      1.557876e+06
# Nb of sec with 6250B < Vol UL < 37500B      2.510078e+05
# Nb of sec with Vol DL < 6250B               8.369502e+07
# Nb of sec with Vol UL < 1250B               1.026864e+08
# Social Media DL (Bytes)                     1.072224e+12
# Social Media UL (Bytes)                     3.612348e+08
# Google DL (Bytes)                           1.095012e+13
# Google UL (Bytes)                           1.415902e+12
# Email DL (Bytes)                            1.072963e+12
# Email UL (Bytes)                            7.288343e+10
# Youtube DL (Bytes)                          4.503173e+13
# Youtube UL (Bytes)                          4.026440e+13
# Netflix DL (Bytes)                          4.522856e+13
# Netflix UL (Bytes)                          4.044311e+13
# Gaming DL (Bytes)                           5.952014e+16
# Gaming UL (Bytes)                           2.287422e+13
# Other DL (Bytes)                            5.914868e+16
# Other UL (Bytes)                            2.274340e+13
# Total UL (Bytes)                            1.271560e+14
# Total DL (Bytes)                            5.960535e+16
# dtype: float64
# Standard Deviation Values:
# Bearer Id                                   2.883600e+18
# Start ms                                    2.886109e+02
# End ms                                      2.880967e+02
# Dur. (ms)                                   5.908418e+04
# IMSI                                        2.144722e+10
# MSISDN/Number                               2.438731e+12
# IMEI                                        2.237359e+13
# Avg RTT DL (ms)                             5.593426e+02
# Avg RTT UL (ms)                             7.652993e+01
# Avg Bearer TP DL (kbps)                     2.397180e+04
# Avg Bearer TP UL (kbps)                     4.625340e+03
# TCP DL Retrans. Vol (Bytes)                 1.172356e+08
# TCP UL Retrans. Vol (Bytes)                 1.577616e+07
# DL TP < 50 Kbps (%)                         1.300522e+01
# 50 Kbps < DL TP < 250 Kbps (%)              6.199592e+00
# 250 Kbps < DL TP < 1 Mbps (%)               4.149070e+00
# DL TP > 1 Mbps (%)                          4.816738e+00
# UL TP < 10 Kbps (%)                         4.622035e+00
# 10 Kbps < UL TP < 50 Kbps (%)               3.216651e+00
# 50 Kbps < UL TP < 300 Kbps (%)              1.620229e+00
# UL TP > 300 Kbps (%)                        1.291972e+00
# HTTP DL (Bytes)                             6.510226e+08
# HTTP UL (Bytes)                             1.319532e+07
# Activity Duration DL (ms)                   5.696376e+06
# Activity Duration UL (ms)                   4.643215e+06
# Dur. (ms).1                                 8.103734e+07
# Nb of sec with 125000B < Vol DL             1.505999e+03
# Nb of sec with 1250B < Vol UL < 6250B       8.918109e+02
# Nb of sec with 31250B < Vol DL < 125000B    1.129733e+03
# Nb of sec with 37500B < Vol UL              4.423211e+02
# Nb of sec with 6250B < Vol DL < 31250B      1.248149e+03
# Nb of sec with 6250B < Vol UL < 37500B      5.010068e+02
# Nb of sec with Vol DL < 6250B               9.148498e+03
# Nb of sec with Vol UL < 1250B               1.013343e+04
# Social Media DL (Bytes)                     1.035482e+06
# Social Media UL (Bytes)                     1.900618e+04
# Google DL (Bytes)                           3.309097e+06
# Google UL (Bytes)                           1.189917e+06
# Email DL (Bytes)                            1.035840e+06
# Email UL (Bytes)                            2.699693e+05
# Youtube DL (Bytes)                          6.710569e+06
# Youtube UL (Bytes)                          6.345423e+06
# Netflix DL (Bytes)                          6.725218e+06
# Netflix UL (Bytes)                          6.359490e+06
# Gaming DL (Bytes)                           2.439675e+08
# Gaming UL (Bytes)                           4.782700e+06
# Other DL (Bytes)                            2.432050e+08
# Other UL (Bytes)                            4.769004e+06
# Total UL (Bytes)                            1.127635e+07
# Total DL (Bytes)                            2.441421e+08
# dtype: float64
# === Interpretation ===
# 1. **Range**: Indicates the spread of values for each variable.
# 2. **Variance and Standard Deviation**: Measure the variability in the dataset. High values suggest greater variation, while low values indicate uniformity.

# %% [markdown]
# ### Bivariate Analysis

# %%
eda.bivariate_analysis()
# Out:
# Showing data for Social Media DL (Bytes):
#    Social Media DL (Bytes)   Total Data
# 0                1545765.0  345629377.0
# 1                1926113.0  707185356.0
# 2                1684053.0  307690973.0
# 3                 644121.0  889352748.0
# 4                 862600.0  607681403.0
# Showing data for Google DL (Bytes):
#    Google DL (Bytes)   Total Data
# 0          1634479.0  345629377.0
# 1          3493924.0  707185356.0
# 2          8535055.0  307690973.0
# 3          9023734.0  889352748.0
# 4          6248284.0  607681403.0
# Showing data for Email DL (Bytes):
#    Email DL (Bytes)   Total Data
# 0         3563542.0  345629377.0
# 1          629046.0  707185356.0
# 2         2690151.0  307690973.0
# 3         1439754.0  889352748.0
# 4         1936496.0  607681403.0
# Showing data for Youtube DL (Bytes):
#    Youtube DL (Bytes)   Total Data
# 0          15854611.0  345629377.0
# 1          20247395.0  707185356.0
# 2          19725661.0  307690973.0
# 3          21388122.0  889352748.0
# 4          15259380.0  607681403.0
# Showing data for Netflix DL (Bytes):
#    Netflix DL (Bytes)   Total Data
# 0           8198936.0  345629377.0
# 1          18338413.0  707185356.0
# 2          17587794.0  307690973.0
# 3          13994646.0  889352748.0
# 4          17124581.0  607681403.0
# Showing data for Gaming DL (Bytes):
#    Gaming DL (Bytes)   Total Data
# 0        278082303.0  345629377.0
# 1        608750074.0  707185356.0
# 2        229584621.0  307690973.0
# 3        799538153.0  889352748.0
# 4        527707248.0  607681403.0
# Showing data for Other DL (Bytes):
#    Other DL (Bytes)   Total Data
# 0       171744450.0  345629377.0
# 1       526904238.0  707185356.0
# 2       410692588.0  307690973.0
# 3       749039933.0  889352748.0
# 4       550709500.0  607681403.0

# %% [markdown]
# ### Dimensionality Reduction

# %%
eda.dimensionality_reduction()
# Out:
# === PCA Explained Variance ===
# 'Principal Component 1: 14.77%'
# 'Principal Component 2: 5.88%'
# 'Principal Component 3: 5.79%'
# 'Principal Component 4: 4.83%'
# 'Principal Component 5: 3.91%'
# 'Principal Component 6: 3.43%'
# 'Principal Component 7: 3.21%'
# 'Principal Component 8: 3.00%'
# 'Principal Component 9: 2.87%'
# 'Principal Component 10: 2.72%'
# 'Principal Component 11: 2.24%'
# 'Principal Component 12: 2.20%'
# 'Principal Component 13: 2.07%'
# 'Principal Component 14: 2.00%'
# 'Principal Component 15: 1.99%'
# 'Principal Component 16: 1.98%'
# 'Principal Component 17: 1.98%'
# 'Principal Component 18: 1.97%'
# 'Principal Component 19: 1.96%'
# 'Principal Component 20: 1.96%'
# 'Principal Component 21: 1.96%'
# 'Principal Component 22: 1.95%'
# 'Principal Component 23: 1.95%'
# 'Principal Component 24: 1.94%'
# 'Principal Component 25: 1.94%'
# 'Principal Component 26: 1.93%'
# 'Principal Component 27: 1.88%'
# 'Principal Component 28: 1.83%'
# 'Principal Component 29: 1.72%'
# 'Principal Component 30: 1.46%'
# 'Principal Component 31: 1.43%'
# 'Principal Component 32: 1.35%'
# 'Principal Component 33: 1.21%'
# 'Principal Component 34: 1.04%'
# 'Principal Component 35: 1.01%'
# 'Principal Component 36: 0.93%'
# 'Principal Component 37: 0.75%'
# 'Principal Component 38: 0.67%'
# 'Principal Component 39: 0.56%'
# 'Principal Component 40: 0.54%'
# 'Principal Component 41: 0.35%'
# 'Principal Component 42: 0.30%'
# 'Principal Component 43: 0.23%'
# 'Principal Component 44: 0.16%'
# 'Principal Component 45: 0.12%'
# 'Principal Component 46: 0.03%'
# 'Principal Component 47: 0.01%'
# 'Principal Component 48: 0.00%'
# 'Principal Component 49: 0.00%'
# 'Principal Component 50: 0.00%'
# 'Principal Component 51: 0.00%'
# === Insights ===
# PCA helps reduce dimensions while retaining most of the variability in the data.
# Select the number of components that explain a significant percentage (e.g., 95%) of the variance.

# %% [markdown]
# ### Correlation Analysis

# %%
eda.correlation_analysis()
# Out:
# === Correlation Matrix ===
#                          Social Media DL (Bytes)  Google DL (Bytes)  \
# Social Media DL (Bytes)                 1.000000          -0.001954
# Google DL (Bytes)                      -0.001954           1.000000
# Email DL (Bytes)                        0.004745          -0.000039
# Youtube DL (Bytes)                     -0.001389           0.001760
# Netflix DL (Bytes)                     -0.001817           0.000548
# Gaming DL (Bytes)                       0.001018          -0.001421
# Other DL (Bytes)                        0.006126          -0.002557
#
#                          Email DL (Bytes)  Youtube DL (Bytes)  \
# Social Media DL (Bytes)          0.004745           -0.001389
# Google DL (Bytes)               -0.000039            0.001760
# Email DL (Bytes)                 1.000000            0.001679
# Youtube DL (Bytes)               0.001679            1.000000
# Netflix DL (Bytes)               0.001351            0.001202
# Gaming DL (Bytes)                0.000050           -0.001861
# Other DL (Bytes)                -0.000444            0.002042
#
#                          Netflix DL (Bytes)  Gaming DL (Bytes)  \
# Social Media DL (Bytes)           -0.001817           0.001018
# Google DL (Bytes)                  0.000548          -0.001421
# Email DL (Bytes)                   0.001351           0.000050
# Youtube DL (Bytes)                 0.001202          -0.001861
# Netflix DL (Bytes)                 1.000000          -0.003201
# Gaming DL (Bytes)                 -0.003201           1.000000
# Other DL (Bytes)                  -0.006000          -0.002591
#
#                          Other DL (Bytes)
# Social Media DL (Bytes)          0.006126
# Google DL (Bytes)               -0.002557
# Email DL (Bytes)                -0.000444
# Youtube DL (Bytes)               0.002042
# Netflix DL (Bytes)              -0.006000
# Gaming DL (Bytes)               -0.002591
# Other DL (Bytes)                 1.000000
# === Insights ===
# Correlation values close to 1 or -1 indicate strong positive or negative relationships.
# Values close to 0 indicate weak or no correlation.
